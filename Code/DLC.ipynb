# %% [markdown]
# # DeepLabCut Toolbox
# https://github.com/AlexEMG/DeepLabCut
#
# This notebook illustrates how to:
# - train a network
# - evaluate a network
# - analyze a novel video
# - create an automatically labeled video
#
# Nath\*, Mathis\* et al.: Using DeepLabCut for markerless pose estimation during behavior across species. Nature Protocols, 2019.
#
# Paper: https://www.nature.com/articles/s41596-019-0176-0
#
# Pre-print: https://www.biorxiv.org/content/biorxiv/early/2018/11/24/476531.full.pdf

# %% [markdown]
# ## Settings

# %%
# %load_ext autoreload
# %autoreload 2
# !pip install 'napari[all]'

import os
import deeplabcut
from pathlib import Path

HERE = Path(os.path.abspath(""))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Requirement already satisfied: napari[all] in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (0.5.2)
# Requirement already satisfied: appdirs>=1.4.4 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from napari[all]) (1.4.4)
# Requirement already satisfied: app-model<0.3.0,>=0.2.8 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from napari[all]) (0.2.8)
# Requirement already satisfied: cachey>=0.2.1 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from napari[all]) (0.2.1)
# Requirement already satisfied: certifi>=2018.1.18 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from napari[all]) (2024.7.4)
# Requirement already satisfied: dask>=2021.10.0 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from dask[array]>=2021.10.0->napari[all]) (2024.8.0)
# Requirement already satisfied: imageio!=2.22.1,>=2.20 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from napari[all]) (2.35.0)
# Requirement already satisfied: jsonschema>=3.2.0 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from napari[all]) (4.23.0)
# Requirement already satisfied: lazy-loader>=0.2 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from napari[all]) (0.4)
# Requirement already satisfied: magicgui>=0.7.0 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from napari[all]) (0.9.1)
# Requirement already satisfied: napari-console>=0.0.9 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from napari[all]) (0.0.9)
# Requirement already satisfied: napari-plugin-engine>=0.1.9 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from napari[all]) (0.2.0)
# Requirement already satisfied: napari-svg>=0.1.8 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from napari[all]) (0.2.0)
# Requirement already satisfied: npe2>=0.7.6 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from napari[all]) (0.7.7)
# Requirement already satisfied: numpydoc>=0.9.2 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from napari[all]) (1.8.0)
# Requirement already satisfied: pandas>=1.3.0 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from napari[all]) (2.2.2)
# Requirement already satisfied: Pillow>=9.0 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from napari[all]) (10.4.0)
# Requirement already satisfied: pint>=0.17 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from napari[all]) (0.24.3)
# Requirement already satisfied: psutil>=5.0 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from napari[all]) (5.9.0)
# Requirement already satisfied: psygnal>=0.5.0 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from napari[all]) (0.11.1)
# Requirement already satisfied: pydantic>=1.9.0 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from napari[all]) (2.8.2)
# Requirement already satisfied: pygments>=2.6.0 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from napari[all]) (2.18.0)
# Requirement already satisfied: PyOpenGL>=3.1.0 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from napari[all]) (3.1.7)
# Requirement already satisfied: PyYAML>=5.1 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from napari[all]) (6.0.2)
# Requirement already satisfied: qtpy>=1.10.0 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from napari[all]) (2.4.1)
# Requirement already satisfied: scikit-image>=0.19.1 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from scikit-image[data]>=0.19.1->napari[all]) (0.24.0)
# Requirement already satisfied: scipy>=1.5.4 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from napari[all]) (1.13.1)
# Requirement already satisfied: superqt>=0.6.7 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from napari[all]) (0.6.7)
# Requirement already satisfied: tifffile>=2022.4.8 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from napari[all]) (2024.8.10)
# Requirement already satisfied: toolz>=0.10.0 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from napari[all]) (0.12.1)
# Requirement already satisfied: tqdm>=4.56.0 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from napari[all]) (4.66.5)
# Requirement already satisfied: typing-extensions>=4.2.0 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from napari[all]) (4.12.2)
# Requirement already satisfied: vispy<0.15,>=0.14.1 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from napari[all]) (0.14.3)
# Requirement already satisfied: wrapt>=1.11.1 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from napari[all]) (1.14.1)
# Requirement already satisfied: numpy<2,>=1.22.2 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from napari[all]) (1.23.5)
# Requirement already satisfied: napari-plugin-manager<0.2.0,>=0.1.0a1 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from napari[all]) (0.1.0)
# Requirement already satisfied: in-n-out>=0.1.5 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from app-model<0.3.0,>=0.2.8->napari[all]) (0.2.1)
# Requirement already satisfied: pydantic-compat>=0.1.1 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from app-model<0.3.0,>=0.2.8->napari[all]) (0.1.2)
# Requirement already satisfied: heapdict in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from cachey>=0.2.1->napari[all]) (1.0.1)
# Requirement already satisfied: click>=8.1 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from dask>=2021.10.0->dask[array]>=2021.10.0->napari[all]) (8.1.7)
# Requirement already satisfied: cloudpickle>=1.5.0 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from dask>=2021.10.0->dask[array]>=2021.10.0->napari[all]) (3.0.0)
# Requirement already satisfied: fsspec>=2021.09.0 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from dask>=2021.10.0->dask[array]>=2021.10.0->napari[all]) (2024.6.1)
# Requirement already satisfied: packaging>=20.0 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from dask>=2021.10.0->dask[array]>=2021.10.0->napari[all]) (24.1)
# Requirement already satisfied: partd>=1.4.0 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from dask>=2021.10.0->dask[array]>=2021.10.0->napari[all]) (1.4.2)
# Requirement already satisfied: importlib-metadata>=4.13.0 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from dask>=2021.10.0->dask[array]>=2021.10.0->napari[all]) (8.2.0)
# Requirement already satisfied: attrs>=22.2.0 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from jsonschema>=3.2.0->napari[all]) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from jsonschema>=3.2.0->napari[all]) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from jsonschema>=3.2.0->napari[all]) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from jsonschema>=3.2.0->napari[all]) (0.20.0)
# Requirement already satisfied: docstring-parser>=0.7 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from magicgui>=0.7.0->napari[all]) (0.16)
# Requirement already satisfied: IPython>=7.7.0 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from napari-console>=0.0.9->napari[all]) (8.12.0)
# Requirement already satisfied: ipykernel>=5.2.0 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from napari-console>=0.0.9->napari[all]) (6.29.5)
# Requirement already satisfied: qtconsole!=4.7.6,!=5.4.2,>=4.5.1 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from napari-console>=0.0.9->napari[all]) (5.5.2)
# Requirement already satisfied: pip in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from napari-plugin-manager<0.2.0,>=0.1.0a1->napari[all]) (24.2)
# Requirement already satisfied: build>=1 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from npe2>=0.7.6->napari[all]) (1.2.1)
# Requirement already satisfied: rich in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from npe2>=0.7.6->napari[all]) (13.7.1)
# Requirement already satisfied: tomli-w in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from npe2>=0.7.6->napari[all]) (1.0.0)
# Requirement already satisfied: tomli in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from npe2>=0.7.6->napari[all]) (2.0.1)
# Requirement already satisfied: typer in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from npe2>=0.7.6->napari[all]) (0.12.4)
# Requirement already satisfied: sphinx>=6 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from numpydoc>=0.9.2->napari[all]) (7.4.7)
# Requirement already satisfied: tabulate>=0.8.10 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from numpydoc>=0.9.2->napari[all]) (0.9.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from pandas>=1.3.0->napari[all]) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from pandas>=1.3.0->napari[all]) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from pandas>=1.3.0->napari[all]) (2024.1)
# Requirement already satisfied: flexcache>=0.3 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from pint>=0.17->napari[all]) (0.3)
# Requirement already satisfied: flexparser>=0.3 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from pint>=0.17->napari[all]) (0.3.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from pydantic>=1.9.0->napari[all]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from pydantic>=1.9.0->napari[all]) (2.20.1)
# Requirement already satisfied: networkx>=2.8 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from scikit-image>=0.19.1->scikit-image[data]>=0.19.1->napari[all]) (3.2.1)
# Requirement already satisfied: pooch>=1.6.0 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from scikit-image[data]>=0.19.1->napari[all]) (1.8.2)
# Requirement already satisfied: freetype-py in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from vispy<0.15,>=0.14.1->napari[all]) (2.4.0)
# Requirement already satisfied: hsluv in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from vispy<0.15,>=0.14.1->napari[all]) (5.0.4)
# Requirement already satisfied: kiwisolver in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from vispy<0.15,>=0.14.1->napari[all]) (1.4.5)
# Requirement already satisfied: numba>=0.57.1 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from napari[all]) (0.60.0)
# Requirement already satisfied: zarr>=2.12.0 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from napari[all]) (2.18.2)
# Requirement already satisfied: pyproject_hooks in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from build>=1->npe2>=0.7.6->napari[all]) (1.1.0)
# Requirement already satisfied: zipp>=0.5 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from importlib-metadata>=4.13.0->dask>=2021.10.0->dask[array]>=2021.10.0->napari[all]) (3.20.0)
# Requirement already satisfied: appnope in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from ipykernel>=5.2.0->napari-console>=0.0.9->napari[all]) (0.1.4)
# Requirement already satisfied: comm>=0.1.1 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from ipykernel>=5.2.0->napari-console>=0.0.9->napari[all]) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from ipykernel>=5.2.0->napari-console>=0.0.9->napari[all]) (1.6.7)
# Requirement already satisfied: jupyter-client>=6.1.12 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from ipykernel>=5.2.0->napari-console>=0.0.9->napari[all]) (7.3.4)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from ipykernel>=5.2.0->napari-console>=0.0.9->napari[all]) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from ipykernel>=5.2.0->napari-console>=0.0.9->napari[all]) (0.1.7)
# Requirement already satisfied: nest-asyncio in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from ipykernel>=5.2.0->napari-console>=0.0.9->napari[all]) (1.6.0)
# Requirement already satisfied: pyzmq>=24 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from ipykernel>=5.2.0->napari-console>=0.0.9->napari[all]) (25.1.2)
# Requirement already satisfied: tornado>=6.1 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from ipykernel>=5.2.0->napari-console>=0.0.9->napari[all]) (6.1)
# Requirement already satisfied: traitlets>=5.4.0 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from ipykernel>=5.2.0->napari-console>=0.0.9->napari[all]) (5.14.3)
# Requirement already satisfied: backcall in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from IPython>=7.7.0->napari-console>=0.0.9->napari[all]) (0.2.0)
# Requirement already satisfied: decorator in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from IPython>=7.7.0->napari-console>=0.0.9->napari[all]) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from IPython>=7.7.0->napari-console>=0.0.9->napari[all]) (0.19.1)
# Requirement already satisfied: pickleshare in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from IPython>=7.7.0->napari-console>=0.0.9->napari[all]) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from IPython>=7.7.0->napari-console>=0.0.9->napari[all]) (3.0.47)
# Requirement already satisfied: stack-data in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from IPython>=7.7.0->napari-console>=0.0.9->napari[all]) (0.6.2)
# Requirement already satisfied: pexpect>4.3 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from IPython>=7.7.0->napari-console>=0.0.9->napari[all]) (4.9.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from numba>=0.57.1->napari[all]) (0.43.0)
# Requirement already satisfied: locket in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from partd>=1.4.0->dask>=2021.10.0->dask[array]>=2021.10.0->napari[all]) (1.0.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from pooch>=1.6.0->scikit-image[data]>=0.19.1->napari[all]) (4.2.2)
# Requirement already satisfied: requests>=2.19.0 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from pooch>=1.6.0->scikit-image[data]>=0.19.1->napari[all]) (2.32.3)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->napari[all]) (1.16.0)
# Requirement already satisfied: sphinxcontrib-applehelp in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from sphinx>=6->numpydoc>=0.9.2->napari[all]) (2.0.0)
# Requirement already satisfied: sphinxcontrib-devhelp in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from sphinx>=6->numpydoc>=0.9.2->napari[all]) (2.0.0)
# Requirement already satisfied: sphinxcontrib-jsmath in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from sphinx>=6->numpydoc>=0.9.2->napari[all]) (1.0.1)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.0 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from sphinx>=6->numpydoc>=0.9.2->napari[all]) (2.1.0)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.9 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from sphinx>=6->numpydoc>=0.9.2->napari[all]) (2.0.0)
# Requirement already satisfied: sphinxcontrib-qthelp in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from sphinx>=6->numpydoc>=0.9.2->napari[all]) (2.0.0)
# Requirement already satisfied: Jinja2>=3.1 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from sphinx>=6->numpydoc>=0.9.2->napari[all]) (3.1.4)
# Requirement already satisfied: docutils<0.22,>=0.20 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from sphinx>=6->numpydoc>=0.9.2->napari[all]) (0.21.2)
# Requirement already satisfied: snowballstemmer>=2.2 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from sphinx>=6->numpydoc>=0.9.2->napari[all]) (2.2.0)
# Requirement already satisfied: babel>=2.13 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from sphinx>=6->numpydoc>=0.9.2->napari[all]) (2.16.0)
# Requirement already satisfied: alabaster~=0.7.14 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from sphinx>=6->numpydoc>=0.9.2->napari[all]) (0.7.16)
# Requirement already satisfied: imagesize>=1.3 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from sphinx>=6->numpydoc>=0.9.2->napari[all]) (1.4.1)
# Requirement already satisfied: pyconify>=0.1.4 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from superqt[iconify]>=0.6.1->magicgui>=0.7.0->napari[all]) (0.1.6)
# Requirement already satisfied: asciitree in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from zarr>=2.12.0->napari[all]) (0.3.3)
# Requirement already satisfied: numcodecs>=0.10.0 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from zarr>=2.12.0->napari[all]) (0.12.1)
# Requirement already satisfied: fasteners in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from zarr>=2.12.0->napari[all]) (0.19)
# Requirement already satisfied: PyQt5!=5.15.0,>=5.12.3 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from napari[all]) (5.15.11)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from rich->npe2>=0.7.6->napari[all]) (3.0.0)
# Requirement already satisfied: shellingham>=1.3.0 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from typer->npe2>=0.7.6->napari[all]) (1.5.4)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from jedi>=0.16->IPython>=7.7.0->napari-console>=0.0.9->napari[all]) (0.8.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from Jinja2>=3.1->sphinx>=6->numpydoc>=0.9.2->napari[all]) (2.1.5)
# Requirement already satisfied: entrypoints in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from jupyter-client>=6.1.12->ipykernel>=5.2.0->napari-console>=0.0.9->napari[all]) (0.4)
# Requirement already satisfied: mdurl~=0.1 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from markdown-it-py>=2.2.0->rich->npe2>=0.7.6->napari[all]) (0.1.2)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from pexpect>4.3->IPython>=7.7.0->napari-console>=0.0.9->napari[all]) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->IPython>=7.7.0->napari-console>=0.0.9->napari[all]) (0.2.13)
# Requirement already satisfied: PyQt5-sip<13,>=12.15 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from PyQt5!=5.15.0,>=5.12.3->napari[all]) (12.15.0)
# Requirement already satisfied: PyQt5-Qt5<5.16.0,>=5.15.2 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from PyQt5!=5.15.0,>=5.12.3->napari[all]) (5.15.14)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.6.0->scikit-image[data]>=0.19.1->napari[all]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.6.0->scikit-image[data]>=0.19.1->napari[all]) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.6.0->scikit-image[data]>=0.19.1->napari[all]) (2.2.2)
# Requirement already satisfied: executing>=1.2.0 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from stack-data->IPython>=7.7.0->napari-console>=0.0.9->napari[all]) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from stack-data->IPython>=7.7.0->napari-console>=0.0.9->napari[all]) (2.4.1)
# Requirement already satisfied: pure-eval in /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages (from stack-data->IPython>=7.7.0->napari-console>=0.0.9->napari[all]) (0.2.3)

# %%
path_video = HERE.parent / "data"  / "eyeCamleft.mj2"
# config_path = deeplabcut.create_new_project('Pupily', 'JR', [str(path_video)], working_directory = HERE.parent / 'data', copy_videos=False, multianimal=False)

# %%
path_config_file = "/Users/jamesrowland/Code/Pupil-to-hypnogram-data/Intermediate/DLC/DLC-Kobayashi-2021-07-19/config.yaml"
deeplabcut.analyze_videos(path_config_file, path_video, videotype="mp4", save_as_csv=True)
# Out:
# Using snapshot-1030000 for model /Users/jamesrowland/Code/Pupil-to-hypnogram-data/Intermediate/DLC/DLC-Kobayashi-2021-07-19/dlc-models/iteration-0/DLCJul19-trainset95shuffle1
# /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer_v1.py:1694: UserWarning: `layer.apply` is deprecated and will be removed in a future version. Please use `layer.__call__` method instead.
#   warnings.warn('`layer.apply` is deprecated and '
# 2024-09-18 13:44:57.081961: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 path_config_file = "/Users/jamesrowland/Code/Pupil-to-hypnogram-data/Intermediate/DLC/DLC-Kobayashi-2021-07-19/config.yaml"
# ----> 2 deeplabcut.analyze_videos(path_config_file, path_video, videotype="mp4", save_as_csv=True)
#
# File /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages/deeplabcut/pose_estimation_tensorflow/predict_videos.py:612, in analyze_videos(config, videos, videotype, shuffle, trainingsetindex, gputouse, save_as_csv, in_random_order, destfolder, batchsize, cropping, TFGPUinference, dynamic, modelprefix, robust_nframes, allow_growth, use_shelve, auto_track, n_tracks, calibrate, identity_only, use_openvino)
#     604 pdindex = pd.MultiIndex.from_product(
#     605     [[DLCscorer], dlc_cfg["all_joints_names"], xyz_labs],
#     606     names=["scorer", "bodyparts", "coords"],
#     607 )
#     609 ##################################################
#     610 # Looping over videos
#     611 ##################################################
# --> 612 Videos = auxiliaryfunctions.get_list_of_videos(videos, videotype, in_random_order)
#     613 if len(Videos) > 0:
#     614     if "multi-animal" in dlc_cfg["dataset_type"]:
#
# File /opt/homebrew/anaconda3/envs/dlc_new/lib/python3.9/site-packages/deeplabcut/utils/auxiliaryfunctions.py:348, in get_list_of_videos(videos, videotype, in_random_order)
#     345 if isinstance(videos, str):
#     346     videos = [videos]
# --> 348 if [os.path.isdir(i) for i in videos] == [True]:  # checks if input is a directory
#     349     """
#     350     Returns all the videos in the directory.
#     351     """
#     352     if not videotype:
#
# TypeError: 'PosixPath' object is not iterable

# %%
deeplabcut.extract_frames(config_path, mode='automatic', algo='uniform', userfeedback=False, crop=False)
# Out:
# Config file read successfully.
# Extracting frames based on uniform ...
# Uniformly extracting of frames from 0.0  seconds to 578.2  seconds.
# [jpeg2000 @ 0x2b1f50f40] unsupported marker 0x6A70 at pos 0x4
# [jpeg2000 @ 0x2b1f50f40] unsupported marker 0xA916 at pos 0x3269
# [jpeg2000 @ 0x2b1f50f40] unsupported marker 0x9757 at pos 0x388C
# [jpeg2000 @ 0x2b1f50f40] unsupported marker 0xA2A1 at pos 0x42D0
# Frames were successfully extracted, for the videos listed in the config.yaml file.
#
# You can now label the frames using the function 'label_frames' (Note, you should label frames extracted from diverse videos (and many videos; we do not recommend training on single videos!)).

# %%
deeplabcut.label_frames(config_path)
# Out:
# Traceback (most recent call last):
#   File "/opt/homebrew/anaconda3/envs/DEEPLABCUT/lib/python3.10/site-packages/napari_deeplabcut/_widgets.py", line 521, in _toggle_line_visibility
#     for artist in self._lines[keypoint]:
# KeyError: 'bodypart1'
# Traceback (most recent call last):
#   File "/opt/homebrew/anaconda3/envs/DEEPLABCUT/lib/python3.10/site-packages/napari_deeplabcut/_widgets.py", line 521, in _toggle_line_visibility
#     for artist in self._lines[keypoint]:
# KeyError: 'bodypart1'
# Traceback (most recent call last):
#   File "/opt/homebrew/anaconda3/envs/DEEPLABCUT/lib/python3.10/site-packages/napari_deeplabcut/_widgets.py", line 521, in _toggle_line_visibility
#     for artist in self._lines[keypoint]:
# KeyError: 'bodypart1'
# Traceback (most recent call last):
#   File "/opt/homebrew/anaconda3/envs/DEEPLABCUT/lib/python3.10/site-packages/napari_deeplabcut/_widgets.py", line 521, in _toggle_line_visibility
#     for artist in self._lines[keypoint]:
# KeyError: 'bodypart1'
# Traceback (most recent call last):
#   File "/opt/homebrew/anaconda3/envs/DEEPLABCUT/lib/python3.10/site-packages/napari_deeplabcut/_widgets.py", line 521, in _toggle_line_visibility
#     for artist in self._lines[keypoint]:
# KeyError: 'bodypart1'
# Traceback (most recent call last):
#   File "/opt/homebrew/anaconda3/envs/DEEPLABCUT/lib/python3.10/site-packages/napari_deeplabcut/_widgets.py", line 521, in _toggle_line_visibility
#     for artist in self._lines[keypoint]:
# KeyError: 'bodypart1'
# Traceback (most recent call last):
#   File "/opt/homebrew/anaconda3/envs/DEEPLABCUT/lib/python3.10/site-packages/napari_deeplabcut/_widgets.py", line 521, in _toggle_line_visibility
#     for artist in self._lines[keypoint]:
# KeyError: 'objectA'
# Traceback (most recent call last):
#   File "/opt/homebrew/anaconda3/envs/DEEPLABCUT/lib/python3.10/site-packages/napari_deeplabcut/_widgets.py", line 521, in _toggle_line_visibility
#     for artist in self._lines[keypoint]:
# KeyError: 'objectA'
# Traceback (most recent call last):
#   File "/opt/homebrew/anaconda3/envs/DEEPLABCUT/lib/python3.10/site-packages/napari_deeplabcut/_widgets.py", line 521, in _toggle_line_visibility
#     for artist in self._lines[keypoint]:
# KeyError: 'bodypart3'
# Traceback (most recent call last):
#   File "/opt/homebrew/anaconda3/envs/DEEPLABCUT/lib/python3.10/site-packages/napari_deeplabcut/_widgets.py", line 521, in _toggle_line_visibility
#     for artist in self._lines[keypoint]:
# KeyError: 'bodypart3'

# %%
deeplabcut.create_training_dataset(config_path)
# Out:
# [(0.95, 1, (array([], dtype=int64), array([0])))]

# %%
deeplabcut.train_network(config_path, shuffle=0, train_fraction=1, trainingsetindex=0, gputouse=None, max_snapshots_to_keep=5, autotune=False, displayiters=100, saveiters=15000, maxiters=30000, allow_growth=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 deeplabcut.train_network(config_path, shuffle=0, train_fraction=1, trainingsetindex=0, gputouse=None, max_snapshots_to_keep=5, autotune=False, displayiters=100, saveiters=15000, maxiters=30000, allow_growth=True)
#
# File /opt/homebrew/anaconda3/envs/DEEPLABCUT/lib/python3.10/site-packages/deeplabcut/compat.py:212, in train_network(config, shuffle, trainingsetindex, max_snapshots_to_keep, displayiters, saveiters, maxiters, allow_growth, gputouse, autotune, keepdeconvweights, modelprefix, superanimal_name, superanimal_transfer_learning, engine, **torch_kwargs)
#      78 """
#      79 Trains the network with the labels in the training dataset.
#      80
#    (...)
#     209     )
#     210 """
#     211 if engine is None:
# --> 212     engine = get_shuffle_engine(
#     213         _load_config(config),
#     214         trainingsetindex=trainingsetindex,
#     215         shuffle=shuffle,
#     216     )
#     218 if engine == Engine.TF:
#     219     from deeplabcut.pose_estimation_tensorflow import train_network
#
# File /opt/homebrew/anaconda3/envs/DEEPLABCUT/lib/python3.10/site-packages/deeplabcut/generate_training_dataset/metadata.py:410, in get_shuffle_engine(cfg, trainingsetindex, shuffle, modelprefix)
#     407     metadata.save()
#     409 metadata = TrainingDatasetMetadata.load(cfg)
# --> 410 shuffle_metadata = metadata.get(trainingsetindex, shuffle)
#     411 if modelprefix:
#     412     # try to get the engine by checking which models folder exists
#     413     engines = find_engines_from_model_folders(
#     414         cfg, trainingsetindex, shuffle, modelprefix
#     415     )
#
# File /opt/homebrew/anaconda3/envs/DEEPLABCUT/lib/python3.10/site-packages/deeplabcut/generate_training_dataset/metadata.py:206, in TrainingDatasetMetadata.get(self, trainset_index, index)
#     200     if (
#     201         shuffle.train_fraction == train_fraction
#     202         and shuffle.index == index
#     203     ):
#     204         return shuffle
# --> 206 raise ValueError(
#     207     f"Could not find a shuffle with trainingset fraction {train_fraction} and "
#     208     f"index {index}"
#     209 )
#
# ValueError: Could not find a shuffle with trainingset fraction 1 and index 0

# %%
config_path
# Out:
# '/Users/jamesrowland/Code/Pupil-to-Hypnogram/data/Pupily-JR-2024-08-16/config.yaml'

# %% [markdown]
# ## create labeled videos

# %%
deeplabcut.create_labeled_video(path_config_file, path_video, videotype="mp4")
# Out:
# Starting to process video: ../Data/Inputs/SNT267_0806.mp4
# Loading ../Data/Inputs/SNT267_0806.mp4 and data.
# [Errno 2] No such file or directory: '../Data/Inputs'

# %% [markdown]
# ## Move output files into outputs directory
# from
# ../Data/Inputs/SNT267_0806DLC_resnet50_DLCJul19shuffle1_280000.csv
#
# to
# ../Data/Intermediate/DLC/Outputs/SNT267_0806DLC_resnet50_DLCJul19shuffle1_280000.csv

# %%
import glob
import shutil
outputs = [glob.glob(f'../Data/Inputs/*{ext}')[0] for ext in ["csv", "h5", "pickle", "labeled.mp4"]]
[shutil.move(output, f'../Data/Intermediate/DLC/Outputs/{output.split("/")[-1]}') for output in outputs]
# Out:
# ['../Data/Intermediate/DLC/Outputs/SNT267_0806DLC_resnet50_DLCJul19shuffle1_1030000.csv',
#  '../Data/Intermediate/DLC/Outputs/SNT267_0806DLC_resnet50_DLCJul19shuffle1_1030000.h5',
#  '../Data/Intermediate/DLC/Outputs/SNT267_0806DLC_resnet50_DLCJul19shuffle1_1030000_meta.pickle',
#  '../Data/Intermediate/DLC/Outputs/SNT267_0806DLC_resnet50_DLCJul19shuffle1_280000_labeled.mp4']
